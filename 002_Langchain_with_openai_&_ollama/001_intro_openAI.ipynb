# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPEN_API_KEY"] = os.getenv("OPEN_API_KEY")

os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY") # this is use for langsmith tracking
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 import os
#       2 from dotenv import load_dotenv
#       3 load_dotenv()
#       4
# ----> 5 os.environ["OPEN_API_KEY"] = os.getenv("OPEN_API_KEY")
#       6
#       7 os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY") # this is use for langsmith tracking
#       8 os.environ["LANGCHAIN_TRACING_V2"] = "true"
#
# File <frozen os>:719, in _Environ.__setitem__(self, key, value)
#     717 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen os>:779, in _createenviron.<locals>.check_str(value)
#     777 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: str expected, not NoneType

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI()
print(llm)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langchain_openai import ChatOpenAI
# ----> 2 llm = ChatOpenAI()
#       3 print(llm)
#
# File c:\Users\deven\Desktop\Gen AI\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\deven\Desktop\Gen AI\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1252, in BaseChatOpenAI.validate_environment(self)
#    1238         self.http_async_client = _build_proxied_async_httpx_client(
#    1239             proxy=self.openai_proxy,
#    1240             verify=global_ssl_context,
#    1241             socket_options=resolved_socket_options,
#    1242         )
#    1243     async_specific = {
#    1244         "http_client": self.http_async_client
#    1245         or _get_default_async_httpx_client(
#    (...)   1250         "api_key": async_api_key_value,
#    1251     }
# -> 1252     self.root_async_client = openai.AsyncOpenAI(
#    1253         **client_params,
#    1254         **async_specific,  # type: ignore[arg-type]
#    1255     )
#    1256     self.async_client = self.root_async_client.chat.completions
#    1257 return self
#
# File c:\Users\deven\Desktop\Gen AI\.venv\Lib\site-packages\openai\_client.py:587, in AsyncOpenAI.__init__(self, api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     585     api_key = os.environ.get("OPENAI_API_KEY")
#     586 if api_key is None:
# --> 587     raise OpenAIError(
#     588         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     589     )
#     590 if callable(api_key):
#     591     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
